# %% [markdown]
# <a href="https://colab.research.google.com/github/sumanthgm-a4/Clustering/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DBSCAN CLUSTERING**

# %% [markdown]
# ## **Data Generation**

# %% [markdown]
# Importing the libraries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Generating sample data

# %%
from sklearn.datasets import make_moons

X, _ = make_moons(n_samples = 500, noise = 0.05, random_state = 42)

# %% [markdown]
# ## **Actual Model**

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps = 0.1, min_samples = 4)

# %%
labels = dbscan.fit_predict(X)

# %% [markdown]
# Actual data

# %%
plt.scatter(X[:, 0], X[:, 1], c = _, cmap = "viridis", marker = "o")
plt.title("Original Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
# Out:
# Text(0, 0.5, 'Feature 2')

# %% [markdown]
# Model predictions

# %%
plt.scatter(X[:, 0], X[:, 1], c = labels, cmap = "viridis", marker = "o")
plt.title("DBSCAN Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
# Out:
# Text(0, 0.5, 'Feature 2')
